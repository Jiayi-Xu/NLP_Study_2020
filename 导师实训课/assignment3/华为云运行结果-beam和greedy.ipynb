# %%
# 安装tensorflow2.0
# !pip install tensorflow-gpu==2.0.0b1
# Out:
# ...
#     100% |████████████████████████████████| 348.9MB 68.8MB/s eta 0:00:01                             | 5.7MB 68.4MB/s eta 0:00:06                              | 10.6MB 96.8MB/s eta 0:00:0404/s eta 0:00:047% |██▎                             | 24.5MB 93.6MB/s eta 0:00:040:05                         | 33.9MB 90.0MB/s eta 0:00:040:04██▎                           | 46.5MB 94.0MB/s eta 0:00:04MB/s eta 0:00:04             | 56.5MB 94.2MB/s eta 0:00:048MB 96.8MB/s eta 0:00:03��█                          | 65.2MB 86.1MB/s eta 0:00:04                   | 70.0MB 89.4MB/s eta 0:00:04                   | 74.4MB 85.4MB/s eta 0:00:04ta 0:00:03��████▊                        | 83.8MB 80.4MB/s eta 0:00:04                       | 87.9MB 93.5MB/s eta 0:00:037MB 91.1MB/s eta 0:00:033MB 88.5MB/s eta 0:00:03   29% |█████████▎                      | 101.5MB 95.2MB/s eta 0:00:03   30% |█████████▊                      | 105.9MB 94.9MB/s eta 0:00:031MB/s eta 0:00:03    32% |██████████▌                     | 11
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0-beta1

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
physical_devices
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Test
#
# # 以下代码执行时候参数配置信息如下：
#
# + embed_size,enc_units,dec_units,attn_units 设置为256
# + 测试集数据量为20000
# + mode 为 test
#
# name | Greedy search |   Beam Search  |
# -|-|-|
# batch_size | 200 | 3 |
# vocab_size | 30000 | 30000 |
# greedy_decode | True | False |
# sample size |20000|10|

# %% [markdown]
# ## 执行greedy search

# %%
# %run test/seq2seq_tf2/bin/main.py
# Out:
# Building the model ...
# Creating the vocab ...
# max_size of vocab was specified as 30000; we now have 30000 words. Stopping reading.
# Finished constructing vocabulary of 30000 total words. Last word added: 查些
# Creating the checkpoint manager
# Model restored
# WARNING:tensorflow:From /home/ma-user/anaconda3/envs/TensorFlow-1.13.1/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py:505: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
# ...

# %%
# %run test/seq2seq_tf2/bin/main.py
# Out:
# Building the model ...
# Creating the vocab ...
# max_size of vocab was specified as 30000; we now have 30000 words. Stopping reading.
# Finished constructing vocabulary of 30000 total words. Last word added: 查些
# Creating the checkpoint manager
# Model restored
# WARNING:tensorflow:From /home/ma-user/anaconda3/envs/TensorFlow-1.13.1/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py:505: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
# ...

# %% [markdown]
# ### min_dec_steps设置为40时的结果

# %%
greedy_search1 = pd.read_csv("/home/ma-user/work/test/datasets/greedy_search1.csv")
greedy_search1
# Out:
#           QID                                         Prediction
# 0          Q1  J794乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 1          Q2  活力80A乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱...
# 2          Q3  活力乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 3          Q4  活力80A80A80A80A80A80A80A80A80A80A80A80A80A80A80...
# 4          Q5  J794乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 5          Q6  J794乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 6          Q7  J794乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 7          Q8  J794乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 8          Q9  活力80A80A80A80A80A80A80A80A80A80A80A80A80A80A80...
# 9         Q10  活力乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 10        Q11  浪迪乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 11        Q12  浪迪乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档...
# 12        Q13  活力80A乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱档乱...
# ...

# %% [markdown]
# ### min_dec_steps设置为2时的结果

# %%
greedy_search2 = pd.read_csv("/home/ma-user/work/test/datasets/greedy_search2.csv")
greedy_search2
# Out:
#           QID                                         Prediction
# 0          Q1  杀菌当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速...
# 1          Q2  执行轴坏三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分...
# 2          Q3  执行轴坏当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场...
# 3          Q4  执行轴坏三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分...
# 4          Q5  杀菌奖赏三分星卡问题所在电子眼奖赏三分星卡问题所在电子眼奖赏三分星卡问题所在电子眼奖赏三分星...
# 5          Q6  杀菌奖赏三分奖赏三分奖赏三分奖赏三分奖赏三分奖赏三分奖赏三分奖赏三分奖赏三分奖赏三分奖赏三分...
# 6          Q7  杀菌奖赏三分星卡当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场...
# 7          Q8  杀菌奖赏三分星卡当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场...
# 8          Q9  杀菌奖赏三分星卡当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场前速当场...
# 9         Q10  杀菌三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分...
# 10        Q11  杀菌奖赏P0421奖赏P0421奖赏P0421奖赏P0421奖赏P0421奖赏P0421奖赏...
# 11        Q12  杀菌奖赏P0421当场一倍轴坏当场前速当场一倍轴坏当场前速当场一倍轴坏当场前速当场一倍轴坏当...
# 12        Q13  执行老式当场前速三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分三分...
# ...

# %% [markdown]
# ## 执行beam search
#
# ### beam size 和batch_size 设置为3
# ### 执行main_beam.py文件
# ### test源文件使用了AutoMaster_TestSet_10.csv
#     + 因为跑全量测试集时候20000条，每条句子又步长可达100，跑起来很久，所以从AutoMaster_TestSet.csv提取了前十条数据进行测试验证

# %%
import pandas as pd
input_data = pd.read_csv("/home/ma-user/work/test/datasets/AutoMaster_TestSet_10.csv")
input_data
# Out:
#    Unnamed: 0  QID    Brand    Model  \
# 0           0   Q1   大众(进口)  高尔夫(进口)
# 1           1   Q2  一汽-大众奥迪     奥迪A6
# 2           2   Q3     上汽大众      帕萨特
# 3           3   Q4    南京菲亚特      派力奥
# 4           4   Q5     东风本田      思铂睿
# 5           5   Q6   上汽通用别克       君威
# 6           6   Q7     众泰汽车   众泰T600
# 7           7   Q8     一汽海马      福美来
# 8           8   Q9   上汽通用五菱    宝骏630
# 9           9  Q10     东风风行    风行SX6
#
#                                             Question  \
# 0                                    我的帕萨特烧机油怎么办怎么办？
# 1                                        修一下多少钱是换还是修
# 2           帕萨特领域    喇叭坏了  店里说方向盘里线坏了 换一根两三百不等 感觉太贵
# 3                                       发动机漏气会有什么征兆？
# 4  请问 那天右后胎扎了订，补了胎后跑高速80多开始有点抖，110时速以上抖动明显，以为是未做动...
# 5       您好，我的是新款君威  今晚开车的时候，突然有一股从发动机舱出来的烧焦味，是什么原因呢？
# 6      众泰T600跑17000了防冻液发现有些少  防冻液是绿色的  我是不是加一样颜色的就行了
# 7  铃木锋驭 跑了11500公里，换了三次机油，今天突然OIL灯一直亮呢，不知道怎么回事？对车有...
# 8                                      轮胎出现这种裂纹需要更换吗
# ...

# %%
# %run test/seq2seq_tf2/bin/main_beam.py
# Out:
# Building the model ...
# Creating the vocab ...
# max_size of vocab was specified as 30000; we now have 30000 words. Stopping reading.
# Finished constructing vocabulary of 30000 total words. Last word added: 查些
# Creating the checkpoint manager
# Model restored
# WARNING:tensorflow:From /home/ma-user/anaconda3/envs/TensorFlow-1.13.1/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py:505: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
# ...

# %%
import pandas as pd
beam_search = pd.read_csv("/home/ma-user/work/test/datasets/beam_search.csv")
beam_search
# Out:
#    QID                                         Prediction
# 0   Q1  [START]五六百块见刹车灯摩擦力这块装划伤翁回来要贵这块装划伤翁回来要贵这块装划伤翁回来...
# 1   Q2  [START]五六百块半桶15.6热会车15.6热会车15.6热会车15.6热会车15.6热...
# 2   Q3  [START]五六百块热会车原车线热会车原车线热会车原车线热会车原车线热会车原车线热会车原车...
# 3   Q4  [START]五六百块见刹车灯摩擦力这块装划伤翁回来要贵这块装划伤翁回来要贵这块装划伤翁回来...
# 4   Q5  [START]五六百块半桶15.6热会车15.6热会车15.6热会车15.6热会车15.6热...
# 5   Q6  [START]五六百块热会车原车线热会车原车线热会车原车线热会车原车线热会车原车线热会车原车...
# 6   Q7  [START]五六百块见刹车灯摩擦力这块装划伤翁回来要贵这块装划伤翁回来要贵这块装划伤翁回来...
# 7   Q8  [START]五六百块半桶15.6热会车15.6热会车15.6热会车15.6热会车15.6热...
# 8   Q9  [START]五六百块热会车原车线热会车原车线热会车原车线热会车原车线热会车原车线热会车原车...
# 9  Q10  [START]五六百块见刹车灯摩擦力这块装划伤翁回来要贵这块装划伤翁回来要贵这块装划伤翁回来...

# %% [markdown]
# # 列出test产出的文件并加载到obs

# %%
# !ls /home/ma-user/work/test/datasets/
# Out:
# 2020_06_06_18_04_18_batch_size_200_epochs_20_max_length_inp_['max_dec_len']_embedding_dim_['embed_size'].csv
# 2020_06_06_19_21_18_batch_size_200_epochs_20_max_length_inp_['max_dec_len']_embedding_dim_['embed_size'].csv
# 2020_06_06_20_08_19_batch_size_3_epochs_20_max_length_inp_['max_dec_len']_embedding_dim_['embed_size'].csv
# AutoMaster_TestSet_10.csv
# AutoMaster_TestSet.csv
# AutoMaster_TrainSet.csv
# csvExtract.py
# greedy_search2.csv
# greedy_search.csv
# reverse_vocab.txt
# sentences.txt
# stopwords.txt
# test_set.seg_x.txt
# train_set.seg_x.txt
# train_set.seg_y.txt
# vocab.txt
# word2vec.txt
# word_index.json
# wv_index_build10.index

# %%
from modelarts.session import Session
session = Session()
session.upload_data(bucket_path="/class-1275-42262/Lab-2210/modelarts22902323/", path="/home/ma-user/work/test/datasets/2020_06_06_20_08_19_batch_size_3_epochs_20_max_length_inp_['max_dec_len']_embedding_dim_['embed_size'].csv")
# Out:
# Successfully upload file /home/ma-user/work/test/datasets/2020_06_06_20_08_19_batch_size_3_epochs_20_max_length_inp_['max_dec_len']_embedding_dim_['embed_size'].csv to OBS class-1275-42262/Lab-2210/modelarts22902323

# %% [markdown]
# # Train
#
# #### 以下代码执行时候参数配置信息如下：
#
# embed_size,enc_units,dec_units,attn_units 设置为256
#
# name | 第一次run配置信息 |   第二次run配置信息  |   第三次run配置信息
# -|-|-|-
# batch_size | 200 | 200 | 512 |
# vocab_size | 10000 | 30000 |30000 |
# steps_per_epoch | 1 | 1300 |1300 |
# epochs | 10 | 20 |20 |
# checkpoint路径|checkpoint|checkpoint_vocab30000|checkpoint|
# Loss |3.3990|2.98|OOM问题|

# %%
# %run test/seq2seq_tf2/bin/main.py
# Out:
# max_size of vocab was specified as 30000; we now have 30000 words. Stopping reading.
# Finished constructing vocabulary of 30000 total words. Last word added: 查些
# true vocab is  <seq2seq_tf2.batcher.Vocab object at 0x7f16f04bdc88>
# 建立word和id的索引关系完成
# Creating the batcher ...
# WARNING:tensorflow:From /home/ma-user/anaconda3/envs/TensorFlow-1.13.1/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py:505: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
# ...
